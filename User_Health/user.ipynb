# %%
import pandas as pd

df   = pd.read_csv("multi_output_training_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   age                    200 non-null    int64
#  1   gender                 200 non-null    str
#  2   weight_kg              200 non-null    float64
#  3   height_cm              200 non-null    float64
#  4   bmi                    200 non-null    float64
#  5   activity_level         200 non-null    str
#  6   has_diabetes           200 non-null    int64
#  7   has_hypertension       200 non-null    int64
#  8   has_thyroid            200 non-null    int64
#  9   has_kidney_disease     200 non-null    int64
#  10  has_obesity            200 non-null    int64
#  11  health_goal            200 non-null    str
#  12  daily_calories_target  200 non-null    float64
#  13  daily_protein_target   200 non-null    float64
#  14  daily_carbs_target     200 non-null    float64
# ...
