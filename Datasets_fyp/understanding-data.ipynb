# %%
import os

dataset_path = "dataset"   # folder you downloaded

classes = os.listdir(dataset_path)

print("Total classes:", len(classes))
print()

total_images = 0

for cls in classes:
    class_path = os.path.join(dataset_path, cls)

    if os.path.isdir(class_path):
        images = os.listdir(class_path)
        num_images = len(images)

        total_images += num_images

        print(f"{cls}: {num_images} images")

print()
print("Total images in dataset:", total_images)
# Out:
# Total classes: 210
#
# adhirasam: 50 images
# aloo_gobi: 50 images
# aloo_matar: 51 images
# aloo_methi: 50 images
# aloo_shimla_mirch: 50 images
# aloo_tikki: 50 images
# amulet_fahita: 25 images
# anarsa: 50 images
# arika: 25 images
# ariselu: 50 images
# Arugula_salad: 25 images
# bandar_laddu: 50 images
# Barbecue_chicken: 25 images
# basundi: 50 images
# beaf burger: 25 images
# Beaf Peanut butter: 25 images
# Beaf stake sandwitch: 25 images
# Beef Bashamel: 26 images
# Beef bashamil: 25 images
# Beef Kufta: 25 images
# beef pesto with rice: 25 images
# Beef roll: 25 images
# beef sati: 25 images
# Beef syraih: 25 images
# beef_fahita: 25 images
# Beef_fahita-removebg-preview: 25 images
# beef_kabsa: 25 images
# bhatura: 50 images
# bhindi_masala: 50 images
# biryani: 50 images
# boondi: 50 images
# Brownies: 25 images
# buffalo sandwich: 25 images
# Buffalo_chicken: 25 images
# BurgaRice_Beef: 25 images
# BurgaRice_chicken: 25 images
# Butter_Chicken: 75 images
# ceasar salad: 25 images
# chak_hao_kheer: 50 images
# cham_cham: 50 images
# chana_masala: 50 images
# chapati: 50 images
# Cheese Cake: 25 images
# chhena_kheeri: 50 images
# chicken burger: 25 images
# chicken kabab: 25 images
# Chicken Mashroam white rice: 26 images
# Chicken_Biryani: 25 images
# Chicken_Crunchy_Oats2: 25 images
# Chicken_Fahita_sandwich: 25 images
# Chicken_Fajita: 25 images
# chicken_fingers: 25 images
# chicken_kabsa: 25 images
# chicken_mandi: 25 images
# chicken_mushroam_sandwich: 25 images
# chicken_peanut_butter: 25 images
# chicken_pizza: 25 images
# chicken_razala: 50 images
# Chicken_Scallop: 25 images
# chicken_shreded: 25 images
# chicken_sweat_and_sour: 25 images
# chicken_Tandory: 25 images
# chicken_tikka: 50 images
# chicken_tikka_masala: 50 images
# chicken_tortila_sandwich: 25 images
# chicken_turyaki: 25 images
# chikki: 50 images
# chinees_fish: 25 images
# chinese_chicken_with_rice: 25 images
# Chocolate Cornflake: 25 images
# creamy_chicken: 25 images
# daal_baati_churma: 50 images
# daal_puri: 50 images
# dal_makhani: 50 images
# dal_tadka: 50 images
# Dawood_Basha: 25 images
# dharwad_pedha: 50 images
# doodhpak: 50 images
# double_ka_meetha: 50 images
# dum_aloo: 50 images
# Egg_and_Spinach_Croissant: 25 images
# Egg_Sandwich: 25 images
# falafel: 25 images
# Fettuccine_Chicken: 25 images
# fool: 25 images
# fruit salad_: 25 images
# fruit_salad: 25 images
# gajar_ka_halwa: 50 images
# gavvalu: 50 images
# ghevar: 50 images
# Granula Yoghort: 25 images
# Greek_Chicken: 25 images
# Greek_Salad: 25 images
# gulab_jamun: 50 images
# high_protine_pizza: 25 images
# honey_chicken: 25 images
# imarti: 50 images
# jalebi: 50 images
# Kabab_Kshkash: 25 images
# kachori: 50 images
# kadai_paneer: 50 images
# kadhi_pakoda: 50 images
# kajjikaya: 50 images
# kakinada_khaja: 50 images
# kalakand: 50 images
# karela_bharta: 50 images
# kino salad: 25 images
# kinoa_salad: 25 images
# kofta: 50 images
# Koshari: 25 images
# KosKosi_fish: 25 images
# kuzhi_paniyaram: 50 images
# labnah_Pie: 25 images
# Lasagna_Bolins_Beef: 25 images
# lassi: 50 images
# Lazy Cake: 25 images
# ledikeni: 50 images
# litti_chokha: 50 images
# lyangcha: 50 images
# maach_jhol: 50 images
# makki_di_roti_sarson_da_saag: 50 images
# malapua: 50 images
# malukiah: 26 images
# maqluba: 24 images
# meatballs_with_mushroom: 25 images
# meatballs_with_nodels: 25 images
# misi_roti: 50 images
# misti_doi: 50 images
# mixixi_sandwich: 25 images
# mix_salad: 25 images
# modak: 50 images
# Muffin_Tin_Mini_Apple_Pies: 25 images
# Mushrooms_Chicken: 25 images
# mysore_pak: 50 images
# naan: 50 images
# navrattan_korma: 50 images
# Nicoise_salad: 25 images
# okra_chicken: 25 images
# omellet_pie: 25 images
# palak_paneer: 50 images
# pancakce_banana: 25 images
# paneer_butter_masala: 50 images
# Parmesan_Chicken: 25 images
# penna_arabiata: 25 images
# pesto_chicken_sandwich: 25 images
# Pesto_Haloom_Sandwich: 25 images
# Pesto_Pasta_Chicken: 25 images
# pesto_with_rice2: 25 images
# phirni: 50 images
# pink pasta: 26 images
# Pistachio Cake: 25 images
# pithe: 50 images
# pizza_tortilla: 25 images
# poha: 50 images
# poornalu: 50 images
# pootharekulu: 50 images
# poreto: 25 images
# prawn and rice: 25 images
# pumkin_salad: 25 images
# pumkin_salad_: 25 images
# qubani_ka_meetha: 50 images
# Qusadrilla_Beef: 25 images
# Qusadrilla_chicken: 25 images
# rabri: 50 images
# rasgulla: 50 images
# ras_malai: 50 images
# red_shawerma: 25 images
# Roast Beef: 25 images
# saffaran: 25 images
# salamon: 25 images
# Salmon_Fillet: 25 images
# sandesh: 50 images
# Sayadia_Fish: 25 images
# scrambel_egg: 25 images
# shankarpali: 50 images
# sheera: 50 images
# sheer_korma: 50 images
# shesh_tawok: 25 images
# shrikhand: 50 images
# sieryeh_chicken: 25 images
# Smoked_salamon_salad: 25 images
# sofle beef: 25 images
# sofle_chicken: 25 images
# sohan_halwa: 50 images
# sohan_papdi: 50 images
# Sombrero_salad: 25 images
# spheghati_beef_pasta: 25 images
# spheghati_chicken_ball: 25 images
# steak_with_maish_potato: 25 images
# strawberries Pudding: 25 images
# Sushi_with_Crab_and_Fruits: 25 images
# sutar_feni: 50 images
# Sweet potato chips: 25 images
# sweet_fish_Fillet: 25 images
# tabolah: 25 images
# Teramisu: 25 images
# Teriyaki_Beef: 25 images
# Thyme manakish: 25 images
# tuna_sandwich: 25 images
# turkey_eggs: 25 images
# Turkey_Roast_Croissant: 25 images
# tuscan_chicken: 25 images
# unni_appam: 50 images
# vegetables_chicken_lasagna: 25 images
# Waffle_with_fruits: 25 images
# white_boiled_rice: 110 images
# white_shawerma: 25 images
# zukini_penna_pasta: 25 images
# _fish_fillet_with_limon_sauce: 25 images
# Éclair: 25 images
#
# Total images in dataset: 7364

# %%
import os
import matplotlib.pyplot as plt

dataset_path = "dataset"

classes = []
counts = []

for cls in os.listdir(dataset_path):
    class_path = os.path.join(dataset_path, cls)

    if os.path.isdir(class_path):
        num_images = len(os.listdir(class_path))
        classes.append(cls)
        counts.append(num_images)

plt.figure(figsize=(12,6))
plt.bar(range(len(classes)), counts)

plt.xlabel("Food Classes")
plt.ylabel("Number of Images")
plt.title("Dataset Distribution")

plt.show()

# %% [markdown]
# Next steps will be remove the typos and make data clean etc
